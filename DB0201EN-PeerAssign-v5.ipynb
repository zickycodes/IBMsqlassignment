# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# <h1 align=center><font size = 5>Assignment: Notebook for Peer Assignment</font></h1>

# %% [markdown]
# # Introduction
#
# Using this Python notebook you will:
#
# 1.  Understand three Chicago datasets
# 2.  Load the three datasets into three tables in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Understand the datasets
#
# To complete the assignment problems in this notebook you will be using three datasets that are available on the city of Chicago's Data Portal:
#
# 1.  <a href="https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01">Socioeconomic Indicators in Chicago</a>
# 2.  <a href="https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01">Chicago Public Schools</a>
# 3.  <a href="https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01">Chicago Crime Data</a>
#
# ### 1. Socioeconomic Indicators in Chicago
#
# This dataset contains a selection of six socioeconomic indicators of public health significance and a “hardship index,” for each Chicago community area, for the years 2008 – 2012.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2](https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 2. Chicago Public Schools
#
# This dataset shows all school level performance data used to create CPS School Report Cards for the 2011-2012 school year. This dataset is provided by the city of Chicago's Data Portal.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 3. Chicago Crime Data
#
# This dataset reflects reported incidents of crime (with the exception of murders where data exists for each victim) that occurred in the City of Chicago from 2001 to present, minus the most recent seven days.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to have these three tables populated with a subset of the whole datasets.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the links below to download and save the datasets (.CSV files):
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">Chicago Census Data</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">Chicago Public Schools</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">Chicago Crime Data</a>
#
# **NOTE**: For the learners who are encountering issues with loading from .csv in DB2 on Firefox, you can download the .txt files and load the data with those:
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.txt?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">Chicago Census Data</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.txt?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">Chicago Public Schools</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.txt?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">Chicago Crime Data</a>
#
# **NOTE:** Ensure you have downloaded the datasets using the links above instead of directly from the Chicago Data Portal. The versions linked here are subsets of the original datasets and have some of the column names modified to be more database friendly which will make it easier to complete this assignment.

# %% [markdown]
# ### Store the datasets in database tables
#
# To analyze the data using SQL, it first needs to be stored in the database.
#
# While it is easier to read the dataset into a Pandas dataframe and then PERSIST it into the database as we saw in Week 3 Lab 3, it results in mapping to default datatypes which may not be optimal for SQL querying. For example a long textual field may map to a CLOB instead of a VARCHAR.
#
# Therefore, **it is highly recommended to manually load the table using the database console LOAD tool, as indicated in Week 2 Lab 1 Part II**. The only difference with that lab is that in Step 5 of the instructions you will need to click on create "(+) New Table" and specify the name of the table you want to create and then click "Next".
#
# <img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/images/LoadingData.png">
#
# ##### Now open the Db2 console, open the LOAD tool, Select / Drag the .CSV file for the first dataset, Next create a New Table, and then follow the steps on-screen instructions to load the data. Name the new tables as follows:
#
# 1.  **CENSUS_DATA**
# 2.  **CHICAGO_PUBLIC_SCHOOLS**
# 3.  **CHICAGO_CRIME_DATA**

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database
#
# The following required modules are pre-installed in the Skills Network Labs environment. However if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda) you may need to install these libraries by removing the `#` sign before `!pip` in the code cell below.

# %%
# These libraries are pre-installed in SN Labs. If running in another environment please uncomment lines below to install them:
# !pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# Ensure we don't load_ext with sqlalchemy>=1.4 (incompadible)
# !pip uninstall sqlalchemy==1.4 -y && pip install sqlalchemy==1.3.24
# !pip install ipython-sql
# Out:
# WARNING: Keyring is skipped due to an exception: Failed to unlock the keyring!
# Collecting ibm_db==3.1.0
#   Using cached ibm_db-3.1.0-cp39-cp39-linux_x86_64.whl
# Collecting ibm_db_sa==0.3.3
#   Using cached ibm_db_sa-0.3.3-py3-none-any.whl
# Collecting sqlalchemy>=0.7.3
#   Using cached SQLAlchemy-1.4.44-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# Collecting greenlet!=0.4.17
#   Using cached greenlet-2.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (535 kB)
# Installing collected packages: greenlet, sqlalchemy, ibm-db-sa, ibm-db
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 2.0.1
#     Uninstalling greenlet-2.0.1:
#       Successfully uninstalled greenlet-2.0.1
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.24
#     Uninstalling SQLAlchemy-1.3.24:
#       Successfully uninstalled SQLAlchemy-1.3.24
#   Attempting uninstall: ibm-db-sa
#     Found existing installation: ibm-db-sa 0.3.3
#     Uninstalling ibm-db-sa-0.3.3:
#       Successfully uninstalled ibm-db-sa-0.3.3
#   Attempting uninstall: ibm-db
#     Found existing installation: ibm-db 3.1.0
#     Uninstalling ibm-db-3.1.0:
#       Successfully uninstalled ibm-db-3.1.0
# Successfully installed greenlet-2.0.1 ibm-db-3.1.0 ibm-db-sa-0.3.3 sqlalchemy-1.4.44
# Found existing installation: SQLAlchemy 1.4.44
# Uninstalling SQLAlchemy-1.4.44:
#   Successfully uninstalled SQLAlchemy-1.4.44
# WARNING: Keyring is skipped due to an exception: Failed to unlock the keyring!
# Collecting sqlalchemy==1.3.24
#   Using cached SQLAlchemy-1.3.24-cp39-cp39-manylinux2010_x86_64.whl (1.3 MB)
# Installing collected packages: sqlalchemy
# Successfully installed sqlalchemy-1.3.24
# Requirement already satisfied: ipython-sql in /home/zicky/.local/lib/python3.9/site-packages (0.4.1)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /home/zicky/.local/lib/python3.9/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /home/zicky/.local/lib/python3.9/site-packages (from ipython-sql) (1.3.24)
# Requirement already satisfied: sqlparse in /home/zicky/.local/lib/python3.9/site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: ipython>=1.0 in /home/zicky/.local/lib/python3.9/site-packages (from ipython-sql) (8.5.0)
# Requirement already satisfied: prettytable<1 in /home/zicky/.local/lib/python3.9/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: jedi>=0.16 in /home/zicky/.local/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (0.18.1)
# Requirement already satisfied: stack-data in /home/zicky/.local/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (0.5.1)
# Requirement already satisfied: matplotlib-inline in /home/zicky/.local/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: decorator in /home/zicky/.local/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /home/zicky/.local/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (3.0.31)
# Requirement already satisfied: traitlets>=5 in /home/zicky/.local/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (5.4.0)
# Requirement already satisfied: backcall in /home/zicky/.local/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/zicky/.local/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (2.13.0)
# Requirement already satisfied: pickleshare in /home/zicky/.local/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/zicky/.local/lib/python3.9/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: wcwidth in /home/zicky/.local/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: asttokens in /home/zicky/.local/lib/python3.9/site-packages (from stack-data->ipython>=1.0->ipython-sql) (2.0.8)
# Requirement already satisfied: executing in /home/zicky/.local/lib/python3.9/site-packages (from stack-data->ipython>=1.0->ipython-sql) (1.1.0)
# Requirement already satisfied: pure-eval in /home/zicky/.local/lib/python3.9/site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.2.2)

# %%
# %load_ext sql

# %% [markdown]
# In the next cell enter your db2 connection string. Recall you created Service Credentials for your Db2 instance in first lab in Week 3. From your Db2 service credentials copy everything after db2:// (except the double quote at the end) and paste it in the cell below after ibm_db_sa://
#
# <img src ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/images/details.png">

# %%
# Remember the connection string is of the format:
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name?security=SSL
# Enter the connection string for your Db2 on Cloud database instance below

# %sql ibm_db_sa://bkx46900:zhtNACNb2jajaMQF@8e359033-a1c9-4643-82ef-8ac06f5107eb.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30120/bludb?security=SSL

# %% [markdown]
# ## Problems
#
# Now write and execute SQL queries to solve assignment problems
#
# ### Problem 1
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %sql select count(*) from BKX46900.CHICAGO_CRIME_DATA ;
# Out:
#  * ibm_db_sa://bkx46900:***@8e359033-a1c9-4643-82ef-8ac06f5107eb.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30120/bludb
# Done.
# [(533,)]

# %% [markdown]
# ### Problem 2
#
# ##### List community areas with per capita income less than 11000.

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM BKX46900.CENSUS_DATA WHERE PER_CAPITA_INCOME < 11000;
# Out:
#  * ibm_db_sa://bkx46900:***@8e359033-a1c9-4643-82ef-8ac06f5107eb.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30120/bludb
# Done.
# [('West Garfield Park',),
#  ('South Lawndale',),
#  ('Fuller Park',),
#  ('Riverdale',)]

# %% [markdown]
# ### Problem 3
#
# ##### List all case numbers for crimes  involving minors?(children are not considered minors for the purposes of crime analysis)

# %%
# %sql select * from BKX46900.CHICAGO_CRIME_DATA where "PRIMARY_TYPE" like "%Minors%" or "DESCRIPTION"like "%Minors%";
# Out:
#  * ibm_db_sa://bkx46900:***@8e359033-a1c9-4643-82ef-8ac06f5107eb.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30120/bludb
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0206N  "%Minors%" is not valid in the context where it is used.  SQLSTATE=42703 SQLCODE=-206
# [SQL: select * from BKX46900.CHICAGO_CRIME_DATA where "PRIMARY_TYPE" like "%Minors%" or "DESCRIPTION" like "%Minors%" ;]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?

# %%
# %sql select * from BKX46900.CHICAGO_CRIME_DATA where "PRIMARY_TYPE" like "%Minors%" or "DESCRIPTION"like "%Minors%";

# %% [markdown]
# ### Problem 5
#
# ##### What kinds of crimes were recorded at schools?

# %%
# %sql select * from BKX46900.CHICAGO_CRIME_DATA where LOCATION_DESCRIPTION = "SCHOOL";
# Out:
#  * ibm_db_sa://bkx46900:***@8e359033-a1c9-4643-82ef-8ac06f5107eb.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30120/bludb
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0206N  "SCHOOL" is not valid in the context where it is used.  SQLSTATE=42703 SQLCODE=-206
# [SQL: select * from BKX46900.CHICAGO_CRIME_DATA where LOCATION_DESCRIPTION = "SCHOOL" ;]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %% [markdown]
# ### Problem 6
#
# ##### List the average safety score for each type of school.

# %%
# %sql select NAME_OF_SCHOOL, SAFETY_SCORE from BKX46900.CHICAGO_PUBLIC_SCHOOLS;
# Out:
#  * ibm_db_sa://bkx46900:***@8e359033-a1c9-4643-82ef-8ac06f5107eb.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30120/bludb
# Done.
# [('Abraham Lincoln Elementary School', 99),
#  ('Adam Clayton Powell Paideia Community Academy Elementary School', 54),
#  ('Adlai E Stevenson Elementary School', 61),
#  ('Agustin Lara Elementary Academy', 56),
#  ('Air Force Academy High School', 49),
#  ('Albany Park Multicultural Academy', 66),
#  ('Albert G Lane Technical High School', 88),
#  ('Albert R Sabin Elementary Magnet School', 67),
#  ('Alcott High School for the Humanities', 70),
#  ('Alessandro Volta Elementary School', 43),
#  ('Alexander Graham Bell Elementary School', 99),
#  ('Alexander Graham Elementary School', 49),
#  ('Alexander Hamilton Elementary School', 73),
#  ('Alexander von Humboldt Elementary School', 31),
#  ('Alex Haley Elementary Academy', 28),
#  ('Alfred David Kohn Elementary School', 19),
#  ('Alfred Nobel Elementary School', 37),
#  ('Alice L Barnard Computer Math & Science Center Elementary School', 46),
#  ('Al Raby High School', 52),
#  ('Ambrose Plamondon Elementary School', 45),
#  ('Amelia Earhart Options for Knowledge Elementary School', 81),
#  ('Ames Middle School', 38),
#  ('Amos Alonzo Stagg Elementary School', 23),
#  ('Ana Roque de Duprey Elementary School', 57),
#  ('Andrew Carnegie Elementary School', 48),
#  ('Andrew Jackson Elementary Language Academy', 86),
#  ('Anna R. Langford Community Academy', 31),
#  ('Annie Keller Elementary Gifted Magnet School', 99),
#  ('A.N. Pritzker School', 59),
#  ('Anthony Overton Elementary School', 32),
#  ('Ariel Elementary Community Academy', None),
#  ('Arna Wendell Bontemps Elementary School', 33),
#  ('Arnold Mireles Elementary Academy', 27),
#  ('Arthur A Libby Elementary School', 36),
#  ('Arthur Dixon Elementary School', 47),
#  ('Arthur E Canty Elementary School', 87),
#  ('Arthur R Ashe Elementary School', None),
#  ('Asa Philip Randolph Elementary School', 15),
#  ('Ashburn Community Elementary School', 48),
#  ('Augustus H Burley Elementary School', 99),
#  ('Austin Business and Entrepreneurship Academy High School', 38),
#  ('Austin O Sexton Elementary School', 23),
#  ('Austin Polytechnical Academy High School', 38),
#  ('Avalon Park Elementary School', 32),
#  ('Barbara Vick Early Childhood & Family Center', None),
#  ('Belmont-Cragin Elementary School', 75),
#  ('Benito Juarez Community Academy High School', 46),
#  ('Benjamin Banneker Elementary School', 36),
#  ('Benjamin E Mays Elementary Academy', 27),
#  ('Bernhard Moos Elementary School', 50),
#  ('Betsy Ross Elementary School', 39),
#  ('Beulah Shoesmith Elementary School', 45),
#  ('Blair Early Childhood Center', None),
#  ('Bret Harte Elementary School', 63),
#  ('Brian Piccolo Elementary Specialty School', 27),
#  ('Brighton Park Elementary School', 55),
#  ('Bronzeville Scholastic Academy High School', 41),
#  ('Burnham Elementary Inclusive Academy', 61),
#  ('Burnside Elementary Scholastic Academy', 51),
#  ('Calmeca Academy of Fine Arts and Dual Language', 58),
#  ('Carl Schurz High School', 48),
#  ('Carl von Linne Elementary School', 68),
#  ('Carrie Jacobs Bond Elementary School', 54),
#  ('Carroll-Rosenwald Specialty Elementary School', 35),
#  ('Carter G Woodson South Elementary School', 26),
#  ('Cesar E Chavez Multicultural Academic Center Elementary School', 54),
#  ('Charles Allen Prosser Career Academy High School', 59),
#  ('Charles Evans Hughes Elementary School', 42),
#  ('Charles Gates Dawes Elementary School', 44),
#  ('Charles G Hammond Elementary School', 40),
#  ('Charles H Wacker Elementary School', 32),
#  ('Charles Kozminski Elementary Community Academy', 36),
#  ('Charles N Holden Elementary School', 53),
#  ('Charles P Caldwell Academy of Math & Science Elementary School', 25),
#  ('Charles P Steinmetz Academic Centre High School', 26),
#  ('Charles R Darwin Elementary School', 58),
#  ('Charles R Henderson Elementary School', 16),
#  ('Charles S Brownell Elementary School', 20),
#  ('Charles S Deneen Elementary School', 55),
#  ('Charles Sumner  Math & Science Community Acad Elementary School', 41),
#  ('Charles W Earle Elementary School', 24),
#  ('Chicago Academy Elementary School', 66),
#  ('Chicago Academy High School', 58),
#  ('Chicago High School for Agricultural Sciences', 87),
#  ('Chicago Military Academy High School', 32),
#  ('Chicago Vocational Career Academy High School', 27),
#  ('Christian Ebinger Elementary School', 78),
#  ('Christian Fenger Academy High School', 36),
#  ('Christopher Columbus Elementary School', 66),
#  ('Clara Barton Elementary School', 25),
#  ('Claremont Academy Elementary School', 36),
#  ('Collins Academy High School', 60),
#  ('Columbia Explorers Elementary Academy', 59),
#  ('Countee Cullen Elementary School', 14),
#  ('Crispus Attucks Elementary School', 45),
#  ('Crown Community Academy of Fine Arts Center Elementary School', 27),
#  ('Cyrus H McCormick Elementary School', None),
#  ('Daniel Boone Elementary School', 52),
#  ('Daniel C Beard Elementary School', None),
#  ('Daniel Hale Williams Prep School of Medicine', 50),
#  ('Daniel J Corkery Elementary School', 39),
#  ('Daniel R Cameron Elementary School', 42),
#  ('Daniel S Wentworth Elementary School', 30),
#  ('Daniel Webster Elementary School', 48),
#  ('David G Farragut Career Academy High School', 43),
#  ('DeVry University Advantage Academy High School', None),
#  ('Dewey Elementary Academy of Fine Arts', 41),
#  ('DeWitt Clinton Elementary School', 47),
#  ('Disney II Magnet School', None),
#  ('Donald Morrill Math & Science Elementary School', 28),
#  ('Douglas Taylor Elementary School', 34),
#  ('Dr Jorge Prieto Math and Science', None),
#  ('Dr  Martin Luther King  Jr  College Prep High School', None),
#  ('Dumas Technology Academy', 19),
#  ('Dunne Technology Academy', 46),
#  ('Durkin Park Elementary School', 61),
#  ('Dvorak Technology Academy', 46),
#  ('Dyett High School', 27),
#  ('Edgar Allan Poe Elementary Classical School', 99),
#  ('Edgebrook Elementary School', 99),
#  ('Edison Park Elementary School', 95),
#  ('Edmond Burke Elementary School', 1),
#  ('Edward A Bouchet Math & Science Academy Elementary School', 33),
#  ('Edward Beasley Elementary Magnet Academic Center', 47),
#  ('Edward C Delano Elementary School', 38),
#  ('Edward Coles Elementary Language Academy', 22),
#  ('Edward Everett Elementary School', None),
#  ('Edward Jenner Elementary Academy of the Arts', 50),
#  ('Edward K Ellington Elementary School', 30),
#  ('Edward N Hurley Elementary School', 77),
#  ('Edward Tilden Career Community Academy High School', 34),
#  ('Edward White Elementary Career Academy', 27),
#  ('Edwin G Foreman High School', 26),
#  ('Elaine O Goodlow Elementary Magnet School', 44),
#  ('Elihu Yale Elementary School', 29),
#  ('Eli Whitney Elementary School', 44),
#  ('Elizabeth H Sutherland Elementary School', 86),
#  ('Elizabeth Peabody Elementary School', 51),
#  ('Eliza Chappell Elementary School', 70),
#  ('Ella Flagg Young Elementary School', 31),
#  ('Ellen H Richards Career Academy High School', 30),
#  ('Ellen Mitchell Elementary School', 99),
#  ('Emil G Hirsch Metropolitan High School', 13),
#  ('Emiliano Zapata Elementary Academy', 60),
#  ('Emmett Louis Till Math and Science Academy', 31),
#  ('Enrico Fermi Elementary School', 30),
#  ('Enrico Tonti Elementary School', None),
#  ('Eric Solorio Academy High School', 67),
#  ('Ernst Prussing Elementary School', 71),
#  ('Esmond Elementary School', 36),
#  ('Eugene Field Elementary School', 42),
#  ('Everett McKinley Dirksen Elementary School', 44),
#  ('Evergreen Academy Middle School', 60),
#  ('Fairfield Elementary Academy', 31),
#  ('Federico Garcia Lorca Elementary School', 53),
#  ('Wilma Rudolph Elementary Learning Center', None),
#  ('Ferdinand Peck Elementary School', 51),
#  ('Fernwood Elementary School', 29),
#  ('Florence B Price Elementary School', 20),
#  ('Florence Nightingale Elementary School', 35),
#  ('Fort Dearborn Elementary School', 34),
#  ('Foster Park Elementary School', 11),
#  ('Francisco I Madero Middle School', 49),
#  ('Francis M McKay Elementary School', 23),
#  ('Francis Parkman Elementary School', 38),
#  ('Francis Scott Key Elementary School', 37),
#  ('Francis W Parker Elementary Community Academy', 30),
#  ('Frank I Bennett Elementary School', 46),
#  ('Frank L Gillespie Elementary School', 27),
#  ('Franklin Elementary Fine Arts Center', 87),
#  ('Frank W Gunsaulus Elementary Scholastic Academy', 46),
#  ('Frank W Reilly Elementary School', 48),
#  ('Franz Peter Schubert Elementary School', None),
#  ('Frazier Prospective IB Magnet Elementary School', 60),
#  ('Frederic Chopin Elementary School', 86),
#  ('Frederick A Douglass Academy High School', 44),
#  ('Frederick Funston Elementary School', 16),
#  ('Frederick Stock Elementary School', None),
#  ('Friedrich Ludwig Jahn Elementary School', 72),
#  ('Friedrich W von Steuben Metropolitan Science High School', 70),
#  ('Gage Park High School', 14),
#  ('Galileo Math & Science Scholastic Academy Elementary School', 65),
#  ('Garrett A Morgan Elementary School', 28),
#  ('Genevieve Melody Elementary School', 61),
#  ('George Armstrong International Studies Elementary School', 59),
#  ('George B McClellan Elementary School', 49),
#  ('George B Swift Elementary Specialty School', 61),
#  ('George F Cassell Elementary School', 76),
#  ('George H Corliss High School', 33),
#  ('George Leland Elementary School', None),
#  ('George Manierre Elementary School', 43),
#  ('George M Pullman Elementary School', 59),
#  ('George Rogers Clark Elementary School', 39),
#  ('George Washington Carver Military Academy High School', 53),
#  ('George Washington Carver Primary School', 25),
#  ('George Washington Elementary School', 58),
#  ('George Washington High School', 46),
#  ('George W Curtis Elementary School', 23),
#  ('George Westinghouse High School', 74),
#  ('George W Tilton Elementary School', 6),
#  ('Gerald Delgado Kanoon Elementary Magnet School', 44),
#  ('Graeme Stewart Elementary School', 49),
#  ('Granville T Woods Math & Science Academy Elementary School', 35),
#  ('Greater Lawndale High School For Social Justice', 43),
#  ('Grover Cleveland Elementary School', 64),
#  ('Guglielmo Marconi Elementary Community Academy', 26),
#  ('Gurdon S Hubbard High School', 42),
#  ('Gwendolyn Brooks College Preparatory Academy High School', 64),
#  ('Hannah G Solomon Elementary School', 78),
#  ('Hanson Park Elementary School', 35),
#  ('Harold Washington Elementary School', 28),
#  ('Harriet Beecher Stowe Elementary School', 28),
#  ('Harriet E Sayre Elementary Language Academy', 68),
#  ('Hawthorne Elementary Scholastic Academy', 92),
#  ('Helen M Hefferan Elementary School', 29),
#  ('Helen Peirce International Studies Elementary School', 58),
#  ('Helge A Haugan Elementary School', 43),
#  ('Henry Clay Elementary School', 38),
#  ('Henry D Lloyd Elementary School', None),
#  ('Henry H Nash Elementary School', 41),
#  ('Henry O Tanner Elementary School', 33),
#  ('Henry R Clissold Elementary School', 45),
#  ('High School of Leadership at South Shore', None),
#  ('Hiram H Belding Elementary School', 64),
#  ('Hope College Preparatory High School', 31),
#  ('Horace Greeley Elementary School', 65),
#  ('Horace Mann Elementary School', 28),
#  ('Horatio May Elementary Community Academy', 42),
#  ('Hyde Park Academy High School', 29),
#  ('Hyman G Rickover Naval Academy High School', 64),
#  ('Ida B Wells Preparatory Elementary Academy', 49),
#  ('Ignance Paderewski Elementary Learning Academy', 31),
#  ('Infinity Math Science and Technology High School', 58),
#  ('Inter-American Elementary Magnet School', 67),
#  ('Ira F Aldridge Elementary School', 39),
#  ('Irene C. Hernandez Middle School for the Advancement of Science', 34),
#  ('Irma C Ruiz Elementary School', 57),
#  ('Irvin C Mollison Elementary School', 44),
#  ("Isabelle C O'Keeffe Elementary School", 17),
#  ('Jackie Robinson Elementary School', None),
#  ('Jacob Beidler Elementary School', 63),
#  ('Jacqueline B Vaughn Occupational High School', 57),
#  ('James B Farnsworth Elementary School', 55),
#  ('James B McPherson Elementary School', 71),
#  ('James E McDade Elementary Classical School', 99),
#  ('James G Blaine Elementary School', 99),
#  ('James Hedges Elementary School', 22),
#  ('James Madison Elementary School', 39),
#  ('James Monroe Elementary School', 45),
#  ('James N Thorp Elementary School', 32),
#  ('James Otis Elementary School', 83),
#  ('James R Doolittle Jr Elementary School', 30),
#  ('James Russell Lowell Elementary School', 39),
#  ('James Shields Elementary School', 38),
#  ('James Wadsworth Elementary School', None),
#  ('James Ward Elementary School', 49),
#  ('James Weldon Johnson Elementary School', 67),
#  ('Jane Addams Elementary School', 56),
#  ('Jane A Neil Elementary School', 42),
#  ('Jean Baptiste Beaubien Elementary School', 63),
#  ('Jean D Lafayette Elementary School', 44),
#  ('Jensen Elementary Scholastic Academy', 35),
#  ('Jesse Owens Elementary Community Academy', None),
#  ('Jesse Sherwood Elementary School', 38),
#  ('Johann W von Goethe Elementary School', 75),
#  ('John A Walsh Elementary School', 60),
#  ('John Barry Elementary School', 35),
#  ('John B Drake Elementary School', 59),
#  ('John B Murphy Elementary School', 80),
#  ('John Calhoun North Elementary School', 52),
#  ('John C Burroughs Elementary School', 50),
#  ('John C Coonley Elementary School', 87),
#  ('John C Dore Elementary School', 74),
#  ('John Charles Haines Elementary School', 32),
#  ('John D Shoop Math-Science Technical Academy Elementary School', 32),
#  ('John F Eberhart Elementary School', 42),
#  ('John Fiske Elementary School', 13),
#  ('John F Kennedy High School', 53),
#  ('John Foster Dulles Elementary School', 42),
#  ('John Greenleaf Whittier Elementary School', 65),
#  ('John Hancock College Preparatory High School', 51),
#  ('John Harvard Elementary School of Excellence', 51),
#  ('John Hay Elementary Community Academy', 44),
#  ('John H Hamline Elementary School', 33),
#  ('John H Kinzie Elementary School', 64),
#  ('John H Vanderpoel Elementary Magnet School', 74),
#  ('John J Audubon Elementary School', 95),
#  ('John J Pershing Elementary Humanities Magnet', None),
#  ('John L Marsh Elementary School', 72),
#  ('John Marshall Metropolitan High School', 51),
#  ('John M Harlan Community Academy High School', None),
#  ('John Milton Gregory Elementary School', 44),
#  ('John M Smyth Elementary School', 37),
#  ('Johnnie Colemon Elementary Academy', 60),
#  ('John Palmer Elementary School', 75),
#  ('John P Altgeld Elementary School', 48),
#  ('John Spry Elementary Community School', 66),
#  ('John T McCutcheon Elementary School', 56),
#  ('John T Pirie Fine Arts & Academic Center Elementary School', 26),
#  ('John W Cook Elementary School', None),
#  ('John W Garvy Elementary School', 60),
#  ('John Whistler Elementary School', 45),
#  ('Jonathan Burr Elementary School', 71),
#  ('Jonathan Y Scammon Elementary School', 44),
#  ('Jordan Elementary Community School', 61),
#  ('Jose De Diego Elementary Community Academy', 57),
#  ('Josefa Ortiz De Dominguez Elementary School', None),
#  ('Joseph Brennemann Elementary School', 50),
#  ('Joseph E Gary Elementary School', 32),
#  ('Josephine C Locke Elementary School', 57),
#  ('Joseph Jungman Elementary School', 36),
#  ('Joseph Kellman Corporate Community Elementary School', 58),
#  ('Joseph Lovett Elementary School', 43),
#  ('Joseph Stockton Elementary School', 37),
#  ('Joseph Warren Elementary School', 33),
#  ('Joshua D Kershaw Elementary School', 62),
#  ('Josiah Pickard Elementary School', 50),
#  ('Joyce Kilmer Elementary School', None),
#  ('Julia C Lathrop Elementary School', 67),
#  ('Julia Ward Howe Elementary School of Excellence', 67),
#  ('Kate S Buckingham Special Education Center', 31),
#  ('Kate S Kellogg Elementary School', 76),
#  ('Kelvyn Park High School', 32),
#  ('Kenwood Academy High School', 63),
#  ('Lake View High School', 64),
#  ('Langston Hughes Elementary School', 28),
#  ('LaSalle Elementary Language Academy', 99),
#  ('LaSalle II Magnet Elementary School', 66),
#  ('Laughlin Falconer Elementary School', 54),
#  ('Laura S Ward Elementary School', None),
#  ('Lawndale Elementary Community Academy', None),
#  ('Lazaro Cardenas Elementary School', None),
#  ('Leif Ericson Elementary Scholastic Academy', 33),
#  ('Lenart Elementary Regional Gifted Center', 79),
#  ('Leslie Lewis Elementary School', 21),
#  ('Lincoln Park High School', 65),
#  ('Lionel Hampton Fine & Performing Arts Elementary School', 42),
#  ('Little Village Elementary School', 45),
#  ('Logandale Middle School', 56),
#  ('Lorenz Brentano Math & Science Academy Elementary School', 57),
#  ('Louis A Agassiz Elementary School', 53),
#  ('Louisa May Alcott Elementary School', None),
#  ('Louis Armstrong Math & Science Elementary School', 42),
#  ('Louis Nettelhorst Elementary School', 58),
#  ('Louis Pasteur Elementary School', 50),
#  ('Ludwig Van Beethoven Elementary School', 40),
#  ("Luke O'Toole Elementary School", 5),
#  ('Luther Burbank Elementary School', 37),
#  ('Lyman A Budlong Elementary School', 59),
#  ('Lyman Trumbull Elementary School', 56),
#  ('Mahalia Jackson Elementary School', 38),
#  ('Mancel Talcott Elementary School', 63),
#  ('Manley Career Academy High School', 41),
#  ('Manuel Perez Elementary School', 45),
#  ('Marcus Moziah Garvey Elementary School', 50),
#  ('Mariano Azuela Elementary School', 54),
#  ('Maria Saucedo Elementary Scholastic Academy', 60),
#  ('Marie Sklodowska Curie Metropolitan High School', 43),
#  ('Marine Military Math and Science Academy', 41),
#  ('Mark Sheridan Elementary Math & Science Academy', 74),
#  ('Mark Skinner Elementary School', 87),
#  ('Mark Twain Elementary School', 67),
#  ('Marquette Elementary School', 15),
#  ('Martha Ruggles Elementary School', 43),
#  ('Martin A Ryerson Elementary School', 40),
#  ('Marvin Camras Elementary School', 54),
#  ('Mary E Courtenay Elementary Language Arts Center', 99),
#  ('Mary E McDowell Elementary School', None),
#  ('Mary Gage Peterson Elementary School', 62),
#  ('Mary Lyon Elementary School', 55),
#  ('Mary Mapes Dodge Elementary Renaissance Academy', 57),
#  ('Mary McLeod Bethune Elementary School', 53),
#  ('Mason High School', 50),
#  ('Matthew A Henson Elementary School', 37),
#  ('Matthew Gallistel Elementary Language Academy', 49),
#  ('Medgar Evers Elementary School', 27),
#  ('Melville W Fuller Elementary School', 22),
#  ('Michael Faraday Elementary School', 35),
#  ('Michael M Byrne Elementary School', 63),
#  ('Michele Clark Academic Prep Magnet High School', None),
#  ('Mildred I Lavizzo Elementary School', 15),
#  ('Milton Brunson Math & Science Specialty Elementary School', 30),
#  ('Minnie Mars Jamieson Elementary School', 64),
#  ('Miriam G Canter Middle School', 57),
#  ('Morgan Park High School', 40),
#  ('Morton School of Excellence', 53),
#  ('Moses Montefiore Special Elementary School', 28),
#  ('Mount Greenwood Elementary School', 84),
#  ('Mount Vernon Elementary School', 31),
#  ('Multicultural Academy of Scholarship', 48),
#  ('Myra Bradwell Communications Arts & Sciences Elementary School', 31),
#  ('Nathanael Greene Elementary School', None),
#  ('Nathan Hale Elementary School', 55),
#  ('Nathaniel Pope Elementary School', 48),
#  ('Nathan R Goldblatt Elementary School', 49),
#  ('Nathan S Davis Elementary School', 43),
#  ('National Teachers Elementary Academy', 67),
#  ('Neal F Simeon Career Academy High School', 52),
#  ('Near North Elementary School', 50),
#  ('New Field Elementary School', None),
#  ('New Millennium High School of Health at Bowen', 17),
#  ('Newton Bateman Elementary School', 55),
#  ('Nicholas Senn High School', 48),
#  ('Nicholson Technology Academy', 48),
#  ('Ninos Heroes Elementary Academic Center', 36),
#  ('Norman A Bridge Elementary School', 67),
#  ('North-Grand High School', 42),
#  ('North River Elementary School', 67),
#  ('Northside College Preparatory High School', 99),
#  ('Percy L Julian High School', 28),
#  ('Northside Learning Center High School', 99),
#  ('Northwest Middle School', 34),
#  ('Norwood Park Elementary School', 99),
#  ('Ogden International High School', 56),
#  ('Ole A Thorp Elementary Scholastic Academy', 70),
#  ('Oliver S Westcott Elementary School', 30),
#  ('Oliver Wendell Holmes Elementary School', 21),
#  ('Oriole Park Elementary School', 99),
#  ('Orozco Fine Arts & Sciences Elementary School', 55),
#  ('Orr Academy High School', None),
#  ('Orville T Bright Elementary School', 18),
#  ('Oscar DePriest Elementary School', 35),
#  ('Oscar F Mayer Elementary School', 67),
#  ('Pablo Casals Elementary School', None),
#  ('Park Manor Elementary School', 28),
#  ('Parkside Elementary Community Academy', None),
#  ('Patrick Henry Elementary School', 45),
#  ('Paul Cuffe Math-Science Technology Academy Elementary School', 51),
#  ('Paul Laurence Dunbar Career Academy High School', 29),
#  ('Paul Revere Elementary School', 36),
#  ('Paul Robeson High School', 29),
#  ('Perkins Bass Elementary School', 28),
#  ('Pershing West Middle School', 46),
#  ('Peter A Reinberg Elementary School', 60),
#  ('Peter Cooper Elementary Dual Language Academy', None),
#  ('Philip Rogers Elementary School', 81),
#  ('Phillip D Armour Elementary School', 36),
#  ('Phillip Murray Elementary Language Academy', 66),
#  ('Phobe Apperson Hearst Elementary School', 33),
#  ('Phoenix Military Academy High School', 53),
#  ('Pilsen Elementary Community Academy', 43),
#  ('Portage Park Elementary School', 62),
#  ('Pulaski International Academy Elmentary School', 68),
#  ('Rachel Carson Elementary School', 38),
#  ('Ralph H Metcalfe Elementary Community Academy', None),
#  ('Ravenswood Elementary School', 46),
#  ('Ray Graham Training Center High School', 90),
#  ('Richard Edwards Elementary School', 48),
#  ('Richard Henry Lee Elementary School', 59),
#  ('Richard J Daley Elementary Academy', 29),
#  ('Richard J Oglesby Elementary School', 44),
#  ('Richard T Crane Technical Preparatory High School', 43),
#  ('Richard Yates Elementary School', 42),
#  ('Roald Amundsen High School', 51),
#  ('Robert A Black Magnet Elementary School', 68),
#  ('Robert Emmet Elementary School', 37),
#  ('Robert Fulton Elementary School', 46),
#  ('Robert Healy Elementary School', 63),
#  ('Robert H Lawrence Elementary School', 19),
#  ('Robert L Grimes Elementary School', 79),
#  ('Robert Lindblom Math & Science Academy High School', 66),
#  ('Robert Nathaniel Dett Elementary School', 48),
#  ('Roberto Clemente Community Academy High School', 44),
#  ('Rodolfo Lozano Bilingual & International Center Elementary Schoo', 55),
#  ('Roger C Sullivan High School', 30),
#  ('Ronald Brown Elementary Community Academy', 31),
#  ('Ronald E McNair Elementary School', 31),
#  ('Rosario Castellanos Elementary School', 36),
#  ('Roswell B Mason Elementary School', 37),
#  ('Rudyard Kipling Elementary School', 52),
#  ('Rueben Salazar Elementary Bilingual Center', 64),
#  ('Rufus M Hitch Elementary School', 64),
#  ('Salmon P Chase Elementary School', 55),
#  ('Samuel Gompers Fine Arts Options Elementary School', 34),
#  ('Sauganash Elementary School', 99),
#  ('Scott Joplin Elementary School', 35),
#  ('Sharon Christa McAuliffe Elementary School', None),
#  ('Sidney Sawyer Elementary School', 57),
#  ('Simon Guggenheim Elementary School', 30),
#  ('Sir Miles Davis Magnet Elementary Academy', 35),
#  ('Skinner North', None),
#  ('Socorro Sandoval Elementary School', None),
#  ('Songhai Elementary Learning Institute', 17),
#  ('South Loop Elementary School', 84),
#  ('South Shore Fine Arts Academy', None),
#  ('Southside Occupational Academy High School', None),
#  ('Spencer Technology Academy', 35),
#  ('Spry Community Links High School', 70),
#  ('Stephen Decatur Classical Elementary School', 99),
#  ('Stephen F Gale Elementary Community Academy', 39),
#  ('Stephen K Hayt Elementary School', 72),
#  ('Stephen T Mather High School', 58),
#  ('Stone Elementary Scholastic Academy', 78),
#  ('Suder Montessori Magnet Elementary School', None),
#  ('Talman Elementary School', 99),
#  ('Tarkington School of Excellence Elementary School', 48),
#  ('TEAM Englewood Community Academy High School', 45),
#  ('Telpochcalli Elementary School', 42),
#  ('Theodore Herzl Elementary School', 41),
#  ('Theodore Roosevelt High School', 42),
#  ('Theophilus Schmid Elementary School', 46),
#  ('Thomas A Edison Regional Gifted Center Elementary School', 91),
#  ('Thomas A Hendricks Elementary Community Academy', 33),
#  ('Thomas Chalmers Specialty Elementary School', 34),
#  ('Thomas Drummond Elementary School', 72),
#  ('Thomas Hoyne Elementary School', 67),
#  ('Thomas J Higgins Elementary Community Academy', None),
#  ('Thomas J Waters Elementary School', 85),
#  ('Thomas Kelly High School', 36),
#  ('Thurgood Marshall Middle School', 39),
#  ('Turner-Drew Elementary Language Academy', 56),
#  ('Uplift Community High School', 50),
#  ('Velma F Thomas Early Childhood Center', None),
#  ('Victor Herbert Elementary School', 50),
#  ('Virgil Grissom Elementary School', 62),
#  ('VOISE Academy High School', 42),
#  ('Walt Disney Magnet Elementary School', None),
#  ('Walter L Newberry Math & Science Academy Elementary School', 71),
#  ('Walter Payton College Preparatory High School', 98),
#  ('Walter Q Gresham Elementary School', 25),
#  ('Walter Reed Elementary School', 29),
#  ('Walter S Christopher Elementary School', None),
#  ('Washington D Smyser Elementary School', 55),
#  ('Washington Irving Elementary School', 43),
#  ('Wells Community Academy High School', 51),
#  ('Wendell E Green Elementary School', 32),
#  ('Wendell Phillips Academy High School', None),
#  ('Wendell Smith Elementary School', 22),
#  ('West Park Elementary Academy', 29),
#  ('West Pullman Elementary School', 23),
#  ('West Ridge Elementary School', 67),
#  ('Whitney M Young Magnet High School', 95),
#  ('Wildwood Elementary School', 99),
#  ('Willa Cather Elementary School', 69),
#  ('William A Hinton Elementary School', 18),
#  ('William Bishop Owen Scholastic Academy Elementary School', 49),
#  ('William B Ogden Elementary School', None),
#  ('William C Goudy Elementary School', 70),
#  ('William C Reavis Math & Science Specialty Elementary School', 48),
#  ('William E B Dubois Elementary School', 47),
#  ('William E Dever Elementary School', 67),
#  ('William F Finkl Elementary School', 56),
#  ('William G Hibbard Elementary School', None),
#  ('William H Brown Elementary School', 36),
#  ('William H King Elementary School', 47),
#  ('William Howard Taft High School', 61),
#  ('William H Prescott Elementary School', 90),
#  ('William H Ray Elementary School', 69),
#  ('William H Ryder Math & Science Specialty Elementary School', 34),
#  ('William H Seward Communication Arts Academy Elementary School', 40),
#  ('William J Bogan High School', 20),
#  ('William J & Charles H Mayo Elementary School', 52),
#  ('William J Onahan Elementary School', 64),
#  ('William Jones College Preparatory High School', 92),
#  ('William K New Sullivan Elementary School', 27),
#  ('William Penn Elementary School', 78),
#  ('William P Gray Elementary School', 57),
#  ('William P Nixon Elementary School', 52),
#  ('William Rainey Harper High School', 22),
#  ('Williams Multiplex Elementary School', None),
#  ('Williams Preparatory Academy Middle School', 49),
#  ('William T Sherman Elementary School', 32),
#  ('William W Carter Elementary School', 13),
#  ('Wolfgang A Mozart Elementary School', 41),
#  ('Woodlawn Community Elementary School', 70),
#  ('World Language Academy High School', 51)]

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %sql SELECT COMMUNITY_AREA_NAME, PERCENT_HOUSEHOLDS_BELOW_POVERTY FROM BKX46900.CENSUS_DATA order by PERCENT_HOUSEHOLDS_BELOW_POVERTY desc limit 5;
# Out:
#  * ibm_db_sa://bkx46900:***@8e359033-a1c9-4643-82ef-8ac06f5107eb.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30120/bludb
# Done.
# [('Riverdale', Decimal('56.5')),
#  ('Fuller Park', Decimal('51.2')),
#  ('Englewood', Decimal('46.6')),
#  ('North Lawndale', Decimal('43.1')),
#  ('East Garfield Park', Decimal('42.4'))]

# %% [markdown]
# ### Problem 8
#
# ##### Which community area is most crime prone?

# %%
# %sql SELECT COMMUNITY_AREA_NAME, PERCENT_HOUSEHOLDS_BELOW_POVERTY FROM BKX46900.CENSUS_DATA order by PERCENT_HOUSEHOLDS_BELOW_POVERTY desc limit 1;
# Out:
#  * ibm_db_sa://bkx46900:***@8e359033-a1c9-4643-82ef-8ac06f5107eb.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30120/bludb
# Done.
# [('Riverdale', Decimal('56.5'))]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Query for the 'community area number' that is most crime prone.
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM BKX46900.CENSUS_DATA WHERE HARDSHIP_INDEX = (SELECT HARDSHIP_INDEX FROM BKX46900.CENSUS_DATA ORDER BY HARDSHIP_INDEX desc limit 1);
# Out:
#  * ibm_db_sa://bkx46900:***@8e359033-a1c9-4643-82ef-8ac06f5107eb.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30120/bludb
# Done.
# []

# %% [markdown]
# ### Problem 10
#
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM BKX46900.CENSUS_DATA WHERE = (SELECT HARDSHIP_INDEX FROM BKX46900.CENSUS_DATA ORDER BY HARDSHIP_INDEX desc limit 1);
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# Copyright © 2020 [cognitiveclass.ai](cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# ## Author(s)
#
# <h4> Hima Vasudevan </h4>
# <h4> Rav Ahuja </h4>
# <h4> Ramesh Sannreddy </h4>
#
# ## Contribtuor(s)
#
# <h4> Malika Singla </h4>
#
# ## Change log
#
# | Date       | Version | Changed by        | Change Description                             |
# | ---------- | ------- | ----------------- | ---------------------------------------------- |
# | 2021-11-17 | 2.6     | Lakshmi           | Updated library                                |
# | 2021-05-19 | 2.4     | Lakshmi Holla     | Updated the question                           |
# | 2021-04-30 | 2.3     | Malika Singla     | Updated the libraries                          |
# | 2021-01-15 | 2.2     | Rav Ahuja         | Removed problem 11 and fixed changelog         |
# | 2020-11-25 | 2.1     | Ramesh Sannareddy | Updated the problem statements, and datasets   |
# | 2020-09-05 | 2.0     | Malika Singla     | Moved lab to course repo in GitLab             |
# | 2018-07-18 | 1.0     | Rav Ahuja         | Several updates including loading instructions |
# | 2018-05-04 | 0.1     | Hima Vasudevan    | Created initial version                        |
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
